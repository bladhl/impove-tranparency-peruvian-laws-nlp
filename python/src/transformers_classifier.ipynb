# %%
# !pip install --upgrade transformers

# %%
from transformers import pipeline

# %%
classifier = pipeline('zero-shot-classification', model='facebook/bart-large-mnli')
# Out:
# Downloading:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
 labels = ["agricultura", "cultura", "economia", "energia minas","justicia","mujer","salud","seguridad","tecnologia","transporte","turismo","medio ambiente","educacion","otros"]
 hypothesis_template = 'This text is about {}.'
 sequence = "Propone declarar de necesidad pública y preferente interés nacional la creación de la Universidad Nacional de los Valle de ríos Apurímac, Ene y Mantaro - UNIVRAEM en el distrito Pichari, provincia de La Convención, región del Cusco."

# %%
prediction = classifier(sequence, labels, hypothesis_template=hypothesis_template, multi_class=True)
print(prediction)
# Out:
# The `multi_class` argument has been deprecated and renamed to `multi_label`. `multi_class` will be removed in a future version of Transformers.
# {'sequence': 'Propone declarar de necesidad pública y preferente interés nacional la creación de la Universidad Nacional de los Valle de ríos Apurímac, Ene y Mantaro - UNIVRAEM en el distrito Pichari, provincia de La Convención, región del Cusco.', 'labels': ['educacion', 'modificacion', 'geografia', 'medio ambiente', 'tecnología', 'economia', 'salud', 'deporte'], 'scores': [0.9713717103004456, 0.6710072755813599, 0.2344815880060196, 0.17336368560791016, 0.11321945488452911, 0.08277924358844757, 0.024222714826464653, 0.014780531637370586]}

# %%
print(prediction['labels'][0])
# Out:
# educacion

# %%
import pandas as pd
df = pd.read_csv('MMerino_period.csv',sep = ';',error_bad_lines=False)
print(df)
# Out:
#       Expediente  ...                                             Objeto
# 0  06643/2020-CR  ...  Propone modificar los artículos 84 y 87 del Re...
# 1  06642/2020-CR  ...  Propone ley que autoriza realizar un Referéndu...
# 2  06641/2020-CR  ...  Propone proteger y promover en el territorio n...
# 3  06640/2020-CR  ...  Propone declarar como una necesidad pública y ...
# 4  06639/2020-CR  ...  Propone modificar los artículos 3, 7, 12 e inc...
# 5  06638/2020-CR  ...  Propone modificar el artículo 2.2. del Decreto...
# 6  06637/2020-CR  ...  Propone declarar de interés nacional y necesid...
# 7  06636/2020-CR  ...  Propone ley que regula el Régimen de Sociedad ...
#
# [8 rows x 8 columns]

# %%
aux = list()

for i in df['Objeto']:

  prediction = classifier(str(i), labels, hypothesis_template=hypothesis_template, multi_class=True)
  topics = prediction['labels'][0]
  print(topics)
  aux.append(topics)

# topics = classifier(df['Objeto'].item(),labels,hypothesis_template=hypothesis_template, multi_class=True)
# df = df.assign(topicos = topics['labels'][0].values)

# %%
print(aux)
print(len(aux))
# Out:
# ['educacion', 'otros', 'otros', 'otros', 'otros', 'educacion', 'cultura', 'transporte', 'otros', 'economia', 'transporte', 'transporte', 'otros', 'otros', 'salud', 'otros', 'otros', 'otros', 'otros', 'otros', 'otros', 'otros', 'otros', 'otros', 'economia', 'otros', 'transporte', 'justicia', 'justicia', 'justicia', 'otros', 'otros', 'salud', 'salud', 'medio ambiente', 'cultura', 'salud', 'otros', 'economia', 'otros', 'educacion', 'educacion', 'otros', 'cultura', 'otros', 'otros', 'otros', 'justicia', 'transporte', 'seguridad', 'mujer', 'otros', 'transporte', 'otros', 'otros', 'otros', 'salud', 'otros', 'transporte', 'educacion', 'otros', 'otros', 'seguridad', 'cultura', 'otros', 'tecnologia', 'medio ambiente', 'medio ambiente', 'transporte', 'educacion', 'transporte', 'otros', 'otros', 'otros', 'otros', 'salud', 'salud', 'seguridad', 'otros', 'educacion', 'otros', 'salud', 'agricultura', 'otros', 'otros', 'transporte', 'otros', 'agricultura', 'educacion', 'educacion', 'agricultura', '
# ...
